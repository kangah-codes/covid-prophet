# %%
import pandas as pd
from fbprophet import Prophet

# %%
df = pd.read_csv("usa.csv")

# %%
df.head()
# Out:
#            ds  y
# 0  2020-01-21  1
# 1  2020-01-22  1
# 2  2020-01-23  1
# 3  2020-01-24  2
# 4  2020-01-25  3

# %%
model = Prophet()
model.fit(df)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = model.make_future_dataframe(periods=261)

# %%
future.tail()
# Out:
#             ds
# 347 2021-01-02
# 348 2021-01-03
# 349 2021-01-04
# 350 2021-01-05
# 351 2021-01-06

# %%
future.head()
# Out:
#           ds
# 0 2020-01-21
# 1 2020-01-22
# 2 2020-01-23
# 3 2020-01-24
# 4 2020-01-25

# %%
forecast = model.predict(future)

# %%
forecast[['ds','yhat','yhat_upper','yhat_lower']]
# Out:
#             ds          yhat    yhat_upper    yhat_lower
# 0   2020-01-21 -7.610296e+02  1.943863e+03 -3.825548e+03
# 1   2020-01-22 -5.257099e+02  2.099661e+03 -3.335456e+03
# 2   2020-01-23  1.017059e+02  2.769436e+03 -2.713478e+03
# 3   2020-01-24  5.847453e+02  3.431056e+03 -2.227975e+03
# 4   2020-01-25  1.283365e+03  3.972753e+03 -1.311516e+03
# ..         ...           ...           ...           ...
# 347 2021-01-02  8.495738e+06  1.101194e+07  5.640155e+06
# 348 2021-01-03  8.524667e+06  1.105277e+07  5.650893e+06
# 349 2021-01-04  8.553641e+06  1.109782e+07  5.660809e+06
# 350 2021-01-05  8.583647e+06  1.114609e+07  5.675351e+06
# 351 2021-01-06  8.613866e+06  1.118928e+07  5.686418e+06
#
# [352 rows x 4 columns]

# %%
forecast.tail()
# Out:
#             ds         trend    yhat_lower    yhat_upper   trend_lower  \
# 347 2021-01-02  8.494473e+06  5.640155e+06  1.101194e+07  5.639393e+06
# 348 2021-01-03  8.524458e+06  5.650893e+06  1.105277e+07  5.650932e+06
# 349 2021-01-04  8.554442e+06  5.660809e+06  1.109782e+07  5.662472e+06
# 350 2021-01-05  8.584426e+06  5.675351e+06  1.114609e+07  5.674011e+06
# 351 2021-01-06  8.614411e+06  5.686418e+06  1.118928e+07  5.686780e+06
#
#       trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 347  1.101458e+07     1264.868849           1264.868849           1264.868849
# 348  1.105562e+07      209.732729            209.732729            209.732729
# 349  1.109987e+07     -800.453095           -800.453095           -800.453095
# 350  1.114957e+07     -779.476216           -779.476216           -779.476216
# 351  1.119196e+07     -544.168819           -544.168819           -544.168819
#
#           weekly  weekly_lower  weekly_upper  multiplicative_terms  \
# 347  1264.868849   1264.868849   1264.868849                   0.0
# 348   209.732729    209.732729    209.732729                   0.0
# 349  -800.453095   -800.453095   -800.453095                   0.0
# 350  -779.476216   -779.476216   -779.476216                   0.0
# 351  -544.168819   -544.168819   -544.168819                   0.0
#
#      multiplicative_terms_lower  multiplicative_terms_upper          yhat
# 347                         0.0                         0.0  8.495738e+06
# 348                         0.0                         0.0  8.524667e+06
# 349                         0.0                         0.0  8.553641e+06
# 350                         0.0                         0.0  8.583647e+06
# 351                         0.0                         0.0  8.613866e+06

# %%
model.plot(forecast)

# %%
model.plot_components(forecast)
